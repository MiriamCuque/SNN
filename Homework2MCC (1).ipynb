# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Ejercicio 1. Apartado A.

# %%
x0=float(input('\n Initial position: ' ))
v0=float(input('\n Initial velocity: ' ))
dt=float(input('\n Time steps: ' ))
n=int(input('\n Number of steps: ' ))
m=float(input('\n Mass value: ' ))
k=float(input('\n Elastic constant value: ' ))

#Creation of array of zeros to include future values
x=np.zeros(n+1)
v=np.zeros(n+1)
t=np.zeros(n+1)

#Initial conditions
t[0] = 0.0
x[0] = x0
v[0] = v0

#Acceleration at t=0
a=-k*x[0]/m

# Calculate new velocity after time dt/2
av=v[0]+(dt/2.0)*a
print("\n v (half step)=",av)

#New position and acceleration at step 1 time t+dt
x[1]=x[0]+dt*av
t[1]=t[0]+dt
a=-k*x[1]/m
i=1

print("\n step",i,", x=",x[i],"a=",a)
print("\n At t=0, x=",x[0],", v=",v[0],", a=",a)

while i<n:
    #Calculate acceleration at present position x(t)
    a=-k*x[i]/m
	  #Velocity change from t-dt/2 to t+dt/2
    av=av+a*dt
    #New position at t+dt
    x[i+1]=x[i]+av*dt
    #Update time
    t[i+1]=t[i]+dt
    #update counter
    i=i+1

#Analytical results
x2 = np.cos(t)

#Plot
plt.plot(t,x, 'ro',t,x2, '-')
plt.ylabel('position x (m)')
plt.xlabel('time (s)')
plt.legend(['Numerical', 'Analytical'])
plt.show()
# Out:
#  Initial position: 1
#
#  Initial velocity: 0
#
#  Time steps: 0.01
#
#  Number of steps: 500
#
#  Mass value: 1
#
#  Elastic constant value: 1
#
#  v (half step)= -0.005
#
#  step 1 , x= 0.99995 a= -0.99995
#
#  At t=0, x= 1.0 , v= 0.0 , a= -0.99995

# %% [markdown]
# Ejercicio 1. Apartado B.

# %%
x0=float(input('\n Initial position: ' ))
v0=float(input('\n Initial velocity: ' ))
dt=float(input('\n Time steps: ' ))
n=int(input('\n Number of steps: ' ))
m=float(input('\n Mass value: ' ))
k=float(input('\n Elastic constant: '))

x = np.zeros(n+1)
t = np.zeros(n+1)
E = np.zeros(n+1)
v = np.zeros(n+1)
av = np.zeros(n+1)
a = np.zeros(n+1)
#Initial conditions
t[0] = 0.0
x[0] = x0
v[0] = v0
E[0]=(m/2.0)*v[0]*v[0]+(k/2)*x[0]*x[0]

#Acceleration at t=0
a[0]=-k*x[0]/m

# Calculate new velocity after time dt/2
av[0]=v[0]+(dt/2.0)*a[0]

#New position and acceleration at step 1 time t+dt
x[1]=x[0]+dt*av[0]
t[1]=t[0]+dt
a[1]=-k*x[1]/m
av[1]=av[0]+a[1]*dt
v[1]=(av[0]+av[1])/2
E[1]=(m/2.0)*v[1]*v[1]+(k/2)*x[1]*x[1]
i=1

while i<n:
    #Calculate acceleration at present position x(t)
    a=-k*x[i]/m
	  #Velocity change from t-dt/2 to t+dt/2
    av[i+1]=av[i]+a*dt
    #Update velocity
    v[i+1]=(av[i]+av[i+1])/2
    #New position at t+dt
    x[i+1]=x[i]+av[i+1]*dt
    #Update time
    t[i+1]=t[i]+dt
    #Update energy
    E[i+1]=(m/2.0)*v[i+1]*v[i+1]+(k/2)*x[i+1]*x[i+1]
    #update counter
    i=i+1

#Plot
plt.plot(t,x, 'ro')
plt.ylabel('position x (m)')
plt.xlabel('time (s)')
plt.show()

plt.plot(t,E/E[0], '-')
plt.ylabel('Energy')
plt.xlabel('time (s)')
plt.show()
# Out:
#  Initial position: 1
#
#  Initial velocity: 0
#
#  Time steps: 0.01
#
#  Number of steps: 500
#
#  Mass value: 1
#
#  Elastic constant: 1
